# %% [markdown]
# # Call me maybe

# %% [markdown]
# #### Mohammed Elalj, William Nouet, David Pei, Henri Tilloy

# %%
from __future__ import division
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import pandas as pd
from datetime import datetime
import re
from collections import OrderedDict
from sklearn import svm, preprocessing, cross_validation
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
import math
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsClassifier

# %% [markdown]
# ### Clean dataset

# %%
def clean(file):
    ads_iphone = pd.read_csv(file)
    
    ads_iphone["PRICE"] = ads_iphone["PRICE"].apply(lambda x: int(re.sub("[^0-9]", "", x)))
    ads_iphone["PRICE"] = ads_iphone["PRICE"].apply(fixPrice)
    ads_iphone["MODEL"] = ads_iphone["TITLE"].apply(getPhoneModel)
    ads_iphone["SIZE"] = ads_iphone["TITLE"].apply(getPhoneSize)
    ads_iphone["UPDATE_DATE"] = ads_iphone["UPDATE_DATE"].apply(convertDateUpdate)
    ads_iphone["POSTED_DATE"] = ads_iphone["POSTED_DATE"].apply(convertDatePosted)
    ads_iphone["SOLD_BY"] = ads_iphone["SOLD_BY"].apply(convertDateSoldby)
    
    long_model = []
    for i in range(len(ads_iphone)):
        if (str(ads_iphone['MODEL'][i]) != 'No') & (str(ads_iphone['SIZE'][i]) != 'No'):
            long_model.append(str(ads_iphone['MODEL'][i]) + ' ' + str(ads_iphone['SIZE'][i]))
        else:
            long_model.append(str(ads_iphone['MODEL'][i]))
    ads_iphone['MODEL SIZE'] = long_model

    ads_iphone.to_csv('data_iphone_cleaned.csv')

# %% [markdown]
# ### Functions used to clean the dataset

# %%
#account for bad PRICE (for example, '100-200' is counted as '100200')
def fixPrice(x):
    if len(str(x)) == 5 or len(str(x)) == 6:
        #take the max of the two values
        digits = [int(i) for i in str(x)]
        digits.reverse()
        max_num = str(digits[2]) + str(digits[1]) + str(digits[0])
        #print index, max_num
        return max_num
    else:
        return x

def getPhoneModel(x):
    models = ["iphone6plus", "iphone6", "iphone5s", "iphone5c" , "iphone5", "iphone4s", "iphone4", "iphone3gs", "iphone3g", "iphone2g"]
    for model in models:
        if re.search(model, x.lower().replace(" ", "")): 
            return model
    return 'No'

def getPhoneSize(x):
    sizes = ["128", "64", "32", "16", "8"]
    for size in sizes:
        if re.search(size + "g", x.lower().replace(" ", "")): 
            return size
    return 'No'

def convertDatePosted(x):
    try:
        return datetime.strptime(x, "%Y-%m-%d  %I:%M%p").strftime("%Y-%m-%d %H:%M")
    except ValueError:
        return None

def convertDateUpdate(x):
    try:
        return datetime.strptime(x, "%Y-%m-%d %H:%M").strftime("%Y-%m-%d %H:%M")
    except ValueError:
        return None

def convertDateSoldby(x):
    try:
        return datetime.strptime(x, "%Y-%m-%d %H:%M:%S.%f").strftime("%Y-%m-%d %H:%M")
    except ValueError:
        return 'No'

# %% [markdown]
# ### Get everything

# %%
def get_everything(file):
    # Load data frame
    df = pd.read_csv(file)
    # Get the cities scrapped 
    cities = np.unique(df['LOCATION'])
    # Get the number of phones per city
    phones_per_location = {}
    for city in cities:
        phones_per_location[city] = len(df[df.LOCATION == city])
        
    # Get the date of the first scrap
    date_first_scrap = df['UPDATE_DATE'][0].split(' ')[0]
    # Define the date format
    date_format = "%Y-%m-%d %H:%M"
    # Make the scrapped date fit datetime
    scrapped_date = datetime.strptime(str(date_first_scrap) + ' 23:59', date_format)
    
    # Define a dictionary to get the number of phones sold per hour
    phones_sold = {}
    # Define a dictionary to get the number of phones sold per location
    phones_sold_per_location = {}
    # Define a dictionary to get the price of phones per location
    price_phones_per_location = {}
    # Define a dictionary to get the price of phones sold per location
    price_phones_sold_per_location = {}
    
    # Go through each city
    for i in range(len(df)):
        location = df['LOCATION'][i]
        sold_date = df['SOLD_BY'][i]
        price = df['PRICE'][i]
        model = df['MODEL'][i]
        
        # Check if this location had been found already or not
        if location not in price_phones_per_location.keys():
            price_phones_per_location[location] = price
        else:
            price_phones_per_location[location] += price
        
        # Check if the phone has been sold
        if sold_date != 'No':
            # Fit datetime 
            sold_date = datetime.strptime(str(sold_date), date_format)
            diff = sold_date - scrapped_date
            days = diff.days
            seconds = diff.seconds
            # Get the number of hours between the scrapped date and the sold date
            hours = days * 24 + seconds // 3600            
            # Minus 1 hour to be coherent 
            hours = (abs(hours) - 1)
            # Check if this hour had been found already or not
            if str(hours) not in phones_sold.keys():
                phones_sold[str(hours)] = 1
            else:
                phones_sold[str(hours)] += 1
                
            # Check if this location had been found already or not
            if location not in phones_sold_per_location.keys():
                phones_sold_per_location[location] = 1
            else:
                phones_sold_per_location[location] += 1
                
            # Check if this location had been found already or not
            if location not in price_phones_sold_per_location.keys():
                price_phones_sold_per_location[location] = price
            else:
                price_phones_sold_per_location[location] += price
    
    # Get the average price of phones sold or not per location
    for city in cities:
        price_phones_per_location[city] = price_phones_per_location[city]/phones_per_location[city]
        if city in phones_sold_per_location.keys():
            price_phones_sold_per_location[city] = price_phones_sold_per_location[city]/phones_sold_per_location[city]

    return phones_per_location, phones_sold_per_location, phones_sold, price_phones_per_location, price_phones_sold_per_location

# %% [markdown]
# ### Get nb of phones (sold or not) and their price per city and model

# %%
def get_everything_df(file):
    # Load data frame
    df = pd.read_csv(file)
    # Get the cities scrapped 
    cities = np.unique(df['LOCATION'])

    # List the models of iPhones with their size
    #models = ['No', 'iphone3gs 8', 'iphone4', 'iphone4 8', 'iphone4 16', 'iphone4 32', 'iphone4 64', 'iphone4 128', 'iphone4s', 'iphone4s 8', 'iphone4s 16', 'iphone4s 32', 'iphone4s 64', 'iphone4s 128', 'iphone5', 'iphone5 8', 'iphone5 16', 'iphone5 32', 'iphone5 64', 'iphone5 128', 'iphone5s', 'iphone5s 16', 'iphone5s 32', 'iphone5s 64', 'iphone5s 128', 'iphone5c', 'iphone5c 8', 'iphone5c 16', 'iphone5c 32', 'iphone5c 64', 'iphone5c 128', 'iphone6', 'iphone6 16', 'iphone6 32', 'iphone6 64', 'iphone6 128', 'iphone6plus', 'iphone6plus 16', 'iphone6plus 64', 'iphone6plus 128']
    models = pd.Series(df['MODEL'].values.ravel()).unique()
    data = pd.DataFrame({'MODEL': models})
    
    # Dataframe of price of iphones on Craigslist
    df_price = pd.DataFrame()
    df_price = df_price.append(data)
    # Dataframe of price of iphones sold
    df_price_sold = pd.DataFrame()
    df_price_sold = df_price_sold.append(data)
    # Dataframe of number of iphones on Craigslist
    df_nb = pd.DataFrame()
    df_nb = df_nb.append(data)
    # Dataframe of number of iphones sold
    df_nb_sold = pd.DataFrame()
    df_nb_sold = df_nb_sold.append(data)
    
    # Go through each location scrapped
    for city in cities:
        model_price = OrderedDict()
        model_nb = OrderedDict()
        model_sold_price = OrderedDict()
        model_sold_nb = OrderedDict()
        for key in models:
            model_price.setdefault(key, 0)
            model_nb.setdefault(key, 0)
            model_sold_price.setdefault(key, 0)
            model_sold_nb.setdefault(key, 0)
        
        for i in range(len(df)):
            location = df['LOCATION'][i]
            if location == city:
                model = df['MODEL SIZE'][i]
                sold_date = df['SOLD_BY'][i]
                price = df['PRICE'][i]
                
                if model != 'No':
                    model_nb[model] += 1
                    model_price[model] += price
                
                if sold_date != 'No':
                    model_sold_nb[model] += 1
                    model_sold_price[model] += price
        
        average_price = []
        average_price_sold = []
        for nb, price, nb_sold, sold_price in zip(model_nb.values(),model_price.values(), model_sold_nb.values(), model_sold_price.values()):
            if nb != 0:
                average_price.append(price/nb)
            else:
                average_price.append('NaN')
            if nb_sold != 0:
                average_price_sold.append(sold_price/nb_sold)
            else:
                average_price_sold.append('NaN')
        
        
        # Fill the dataframes per city
        df_price[city] = average_price
        df_price_sold[city] = average_price_sold
        df_nb[city] = model_nb.values()
        df_nb_sold[city] = model_sold_nb.values()
        
    return df_price, df_price_sold, df_nb, df_nb_sold

# %% [markdown]
# ### Graph phones sold

# %%
def graph_phones_sold(phones_sold):
    plt.plot(phones_sold.keys(), phones_sold.values())
    plt.xlabel('Hour')
    plt.ylabel('Number of phones sold')
    plt.title('Phones sold per hour')
    plt.legend(loc = 'best') 
    plt.show()

# %% [markdown]
# ### Clean Data

# %%
#file = 'iPhone_2015-04-28.csv'
#file1 = '3days.csv'
file2 = '7days.csv'
# Clean dataset
#clean(file1)
clean(file2)
#file = 'data_iphone_cleaned.csv'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-61-05a00cff1f4d> in <module>()
#       4 # Clean dataset
#       5 #clean(file1)
# ----> 6 clean(file2)
#       7 #file = 'data_iphone_cleaned.csv'
#
# <ipython-input-2-9424dd7f585b> in clean(file)
#       2     ads_iphone = pd.read_csv(file)
#       3
# ----> 4     ads_iphone["PRICE"] = ads_iphone["PRICE"].apply(lambda x: int(re.sub("[^0-9]", "", x)))
#       5     ads_iphone["PRICE"] = ads_iphone["PRICE"].apply(fixPrice)
#       6     ads_iphone["MODEL"] = ads_iphone["TITLE"].apply(getPhoneModel)
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/series.pyc in apply(self, func, convert_dtype, args, **kwds)
#    2056             values = lib.map_infer(values, lib.Timestamp)
#    2057
# -> 2058         mapped = lib.map_infer(values, f, convert=convert_dtype)
#    2059         if len(mapped) and isinstance(mapped[0], Series):
#    2060             from pandas.core.frame import DataFrame
#
# pandas/src/inference.pyx in pandas.lib.map_infer (pandas/lib.c:57158)()
#
# <ipython-input-2-9424dd7f585b> in <lambda>(x)
#       2     ads_iphone = pd.read_csv(file)
#       3
# ----> 4     ads_iphone["PRICE"] = ads_iphone["PRICE"].apply(lambda x: int(re.sub("[^0-9]", "", x)))
#       5     ads_iphone["PRICE"] = ads_iphone["PRICE"].apply(fixPrice)
#       6     ads_iphone["MODEL"] = ads_iphone["TITLE"].apply(getPhoneModel)
#
# /usr/lib/python2.7/re.pyc in sub(pattern, repl, string, count, flags)
#     149     a callable, it's passed the match object and must return
#     150     a replacement string to be used."""
# --> 151     return _compile(pattern, flags).sub(repl, string, count)
#     152
#     153 def subn(pattern, repl, string, count=0, flags=0):
#
# TypeError: buffer size mismatch

# %% [markdown]
# ### Main

# %%
#models = ['iphone3gs 8', 'iphone4', 'iphone4 8', 'iphone4 16', 'iphone4 32', 'iphone4 64', 'iphone4 128', 'iphone4s', 'iphone4s 8', 'iphone4s 16', 'iphone4s 32', 'iphone4s 64', 'iphone4s 128', 'iphone5', 'iphone5 8', 'iphone5 16', 'iphone5 32', 'iphone5 64', 'iphone5 128', 'iphone5s', 'iphone5s 16', 'iphone5s 32', 'iphone5s 64', 'iphone5s 128', 'iphone5c', 'iphone5c 8', 'iphone5c 16', 'iphone5c 32', 'iphone5c 64', 'iphone5c 128', 'iphone6', 'iphone6 16', 'iphone6 32', 'iphone6 64', 'iphone6 128', 'iphone6plus', 'iphone6plus 16', 'iphone6plus 64', 'iphone6plus 128']
models = pd.Series(df['MODEL'].values.ravel()).unique()
# Get everything
phones_per_location, phones_sold_per_location, phones_sold, price_phones_per_location, price_phones_sold_per_location = get_everything(file)
#print phones_sold
#print phones_per_location
#print phones_sold_per_location
#print price_phones_per_location
#print price_phones_sold_per_location

# Get dataframes of number of phones (sold) and their price per city and model
df_price, df_price_sold, df_nb, df_nb_sold = get_everything_df(file)

# Plot the number of phones sold per hour
#graph_phones_sold(phones_sold)

# %% [markdown]
# # Machine Learning

# %% [markdown]
# ### Preparing Data

# %%
pd.set_option('display.max_rows', 3000)

data_3days = pd.read_csv('3days_cleaned.csv',index_col=0)
df_3days = pd.DataFrame()
df_3days['PRICE'] = data_3days['PRICE']
df_3days['LOCATION'] = data_3days['LOCATION']
df_3days['MODEL'] = data_3days['MODEL']
df_3days['SIZE'] = data_3days['SIZE']
df_3days['SOLD_BY'] = data_3days['SOLD_BY']
df_3days = df_3days.drop(df_3days[df_3days.LOCATION == 'sandiego'].index) #sandiego had a LOT of spam ads

data_week = pd.read_csv('7days_cleaned.csv',index_col=0)
df_week = pd.DataFrame()
df_week['PRICE'] = data_week['PRICE']
df_week['LOCATION'] = data_week['LOCATION']
df_week['MODEL'] = data_week['MODEL']
df_week['SIZE'] = data_week['SIZE']
df_week['SOLD_BY'] = data_week['SOLD_BY']
#df = df.drop(df[<some boolean condition>].index)
df_week = df_week.drop(df_week[df_week.LOCATION == 'sandiego'].index) #sandiego had a LOT of spam ads

def transform(df):
    #Normalize PRICE
    df['PRICE'] = (df['PRICE'] - df['PRICE'].mean())/df['PRICE'].std()
    #df['PRICE'] = df['PRICE'].apply(math.log)
    
    #Label Encode LOCATION
    encoderL = preprocessing.LabelEncoder()
    encoderL.fit(df['LOCATION'])
    df['LOCATION'] = encoderL.transform(df['LOCATION'])
    
    #Label Encode MODEL
    encoderM = preprocessing.LabelEncoder()
    encoderM.fit(df['MODEL'])
    df['MODEL'] = encoderM.transform(df['MODEL'])
    
    #Label Encode SIZE
    encoderS = preprocessing.LabelEncoder()
    encoderS.fit(df['SIZE'])
    df['SIZE'] = encoderS.transform(df['SIZE'])
    
    #Label Encode SOLD_BY target_label
    def convertToYes(x):
        if x != 'No':
            return 'Yes'
        else:
            return 'No'
        
    df['SOLD_BY'] = df['SOLD_BY'].apply(convertToYes)
    encoderS = preprocessing.LabelEncoder()
    encoderS.fit(df['SOLD_BY'])
    df['SOLD_BY'] = encoderS.transform(df['SOLD_BY'])
    
    return df

print df_week
df_3days = transform(df_3days)
df_week = transform(df_week)
print df_3days
print df_week
# Out:
#        PRICE       LOCATION        MODEL SIZE           SOLD_BY
# 0        450  San Francisco      iphone6   No  2015-04-30 00:06
# 1        325  San Francisco     iphone5s   No  2015-04-30 00:06
# 2        320  San Francisco     iphone5s   No                No
# 3        275  San Francisco      iphone5   32                No
# 4        580  San Francisco      iphone6   64  2015-04-30 00:06
# 5        200  San Francisco      iphone5   16  2015-05-02 15:52
# 6        550  San Francisco      iphone6   No                No
# 7        280  San Francisco      iphone5   16                No
# 8        350  San Francisco     iphone5s   32  2015-05-02 15:52
# 9        450  San Francisco      iphone6   16  2015-04-30 00:06
# 10       700  San Francisco  iphone6plus   64  2015-05-01 09:42
# 11       350  San Francisco     iphone5s   32  2015-05-02 15:52
# 12       380  San Francisco     iphone5s   64                No
# 13       600  San Francisco      iphone6   16                No
# 14       600  San Francisco      iphone6   16                No
# 15       120  San Francisco      iphone4   16                No
# 16       600  San Francisco  iphone6plus   64                No
# 17       180  San Francisco     iphone4s   No                No
# 18       299  San Francisco     iphone5s   64  2015-05-01 09:42
# 19       240  San Francisco      iphone5   32  2015-04-29 11:59
# 20       600  San Francisco  iphone6plus   No  2015-05-03 11:36
# 21       120  San Francisco     iphone4s    8                No
# 22       140  San Francisco     iphone4s   No                No
# 23       700  San Francisco  iphone6plus   No  2015-04-30 00:06
# 24       899  San Francisco  iphone6plus  128  2015-05-04 13:43
# 25       150  San Francisco      iphone5   16  2015-04-30 00:06
# 26       200  San Francisco     iphone5s   No  2015-04-30 00:06
# 27       700  San Francisco  iphone6plus   64  2015-04-30 11:53
# 28       650  San Francisco  iphone6plus   64                No
# 29       600  San Francisco      iphone6   64  2015-05-02 15:52
# 30       350  San Francisco     iphone5s   No  2015-04-29 11:59
# 31       300  San Francisco     iphone5s   16  2015-05-02 15:52
# 32       280  San Francisco      iphone5   16                No
# 33       275  San Francisco     iphone5s   16  2015-05-04 23:45
# 34       100  San Francisco      iphone5   16                No
# 35       150  San Francisco     iphone4s   16                No
# 36       225  San Francisco      iphone5   16                No
# 37       110  San Francisco      iphone4   32  2015-05-02 15:52
# 38       125  San Francisco     iphone4s   16  2015-05-02 15:52
# 39       325  San Francisco     iphone5s   32  2015-04-30 00:06
# 40       150  San Francisco     iphone5s    8                No
# 41       320  San Francisco      iphone5   64                No
# 42       200  San Francisco     iphone5c    8  2015-04-30 00:06
# 43       700  San Francisco      iphone6   64  2015-05-04 23:45
# 44        70  San Francisco    iphone3gs   No                No
# 45       350  San Francisco     iphone5s   16  2015-05-02 15:52
# 46       250  San Francisco     iphone5c   16                No
# 47       250  San Francisco     iphone5c   16                No
# 48       200  San Francisco     iphone5s   No                No
# 49       600  San Francisco      iphone6   No                No
# 171      140    Los Angeles      iphone4    8  2015-05-04 23:45
# 172      340    Los Angeles     iphone5s   32  2015-04-30 00:06
# 173      500    Los Angeles      iphone6   No  2015-04-29 11:59
# 174      650    Los Angeles      iphone6   64                No
# 175      180    Los Angeles     iphone4s    8                No
# 176      315    Los Angeles     iphone5s   No                No
# 177      180    Los Angeles      iphone5   No                No
# 178      700    Los Angeles  iphone6plus  128  2015-04-29 11:59
# 179      450    Los Angeles      iphone6   No                No
# 180   320430    Los Angeles      iphone5   No                No
# 181      515    Los Angeles      iphone6   No                No
# 182      120    Los Angeles     iphone4s   16  2015-05-02 15:52
# 183      600    Los Angeles      iphone6   No  2015-04-30 00:06
# 184      180    Los Angeles     iphone4s   16  2015-05-04 23:45
# 185       60    Los Angeles     iphone5c   No  2015-05-01 09:42
# 186      250    Los Angeles      iphone5   32                No
# 187      289    Los Angeles      iphone5   32                No
# 188      600    Los Angeles  iphone6plus   No  2015-05-01 09:42
# 189      220    Los Angeles      iphone5   16  2015-05-01 09:42
# 190      350    Los Angeles      iphone5   64                No
# 191      300    Los Angeles     iphone5s   No                No
# 192      450    Los Angeles      iphone6   No                No
# 193      200    Los Angeles     iphone4s   16                No
# 194      100    Los Angeles      iphone4   16                No
# 195      600    Los Angeles      iphone6   No                No
# 196      220    Los Angeles      iphone5   16                No
# 197      150    Los Angeles      iphone5   16                No
# 198      400    Los Angeles      iphone6   64                No
# 199      270    Los Angeles      iphone5   No                No
# 200      180    Los Angeles      iphone5   16                No
# 201      150    Los Angeles     iphone4s   32  2015-05-02 15:52
# 202      740    Los Angeles  iphone6plus   64                No
# 203      250    Los Angeles     iphone5c   No                No
# 204      250    Los Angeles      iphone5   16                No
# 205      250    Los Angeles     iphone5s   16                No
# 206      250    Los Angeles     iphone5s   16  2015-04-30 11:53
# 207      100    Los Angeles     iphone5c   32  2015-04-30 11:53
# 208      280    Los Angeles     iphone5s   16  2015-05-02 23:44
# 209      250    Los Angeles      iphone5   No                No
# 210      600    Los Angeles      iphone6  128                No
# 211      320    Los Angeles     iphone5s   32                No
# 212      225    Los Angeles      iphone5   16                No
# 213      370    Los Angeles     iphone5s   32                No
# 214      400    Los Angeles     iphone5s   64  2015-05-02 23:44
# 215      250    Los Angeles      iphone5   No                No
# 216      245    Los Angeles     iphone5c   16  2015-05-03 23:38
# 217      500    Los Angeles     iphone5s   No                No
# 218      450    Los Angeles     iphone5s   No                No
# 219      150    Los Angeles      iphone5   64  2015-05-01 11:49
# 220      300    Los Angeles      iphone5   No  2015-05-01 11:49
# 221      150    Los Angeles     iphone5s   No  2015-04-29 12:00
# 222      280    Los Angeles      iphone5   32                No
# 223      115    Los Angeles     iphone5s   32  2015-05-03 23:38
# 224      320    Los Angeles     iphone5s   No  2015-05-01 09:42
# 225       82    Los Angeles      iphone4   No                No
# 226      760    Los Angeles  iphone6plus   64                No
# 227      200    Los Angeles     iphone5c   No                No
# 228       80    Los Angeles     iphone4s   16  2015-05-03 11:36
# 229      850    Los Angeles  iphone6plus  128                No
# 230      120    Los Angeles     iphone4s    8  2015-04-30 11:54
# 231      350        chicago     iphone5s   16                No
# 232      250        chicago     iphone5c   16                No
# 233      200        chicago  iphone6plus   64  2015-04-30 00:06
# 234      250        chicago      iphone5   32                No
# 235      195        chicago      iphone5   16  2015-05-01 09:42
# 236      250        chicago     iphone5c   16  2015-05-04 23:45
# 237      220        chicago      iphone5   No                No
# 238      650        chicago      iphone6   64                No
# 239      175        chicago     iphone5c   16  2015-05-02 15:52
# 240   175200        chicago      iphone5   No  2015-05-01 09:42
# 241       85        chicago     iphone4s   16                No
# 242      150        chicago     iphone4s   16                No
# 243      550        chicago      iphone6   16                No
# 244      350        chicago      iphone5   16  2015-04-30 11:54
# 245      130        chicago     iphone4s   16                No
# 246      240        chicago     iphone5s   No                No
# 247      300        chicago     iphone5s   No                No
# 248      200        chicago      iphone5   No                No
# 249      800        chicago      iphone6   64                No
# 250      200        chicago      iphone6   64  2015-05-01 09:42
# 251      380        chicago     iphone5s   16                No
# 252      400        chicago     iphone5s   16                No
# 253      200        chicago      iphone5   32  2015-05-03 23:38
# 254      280        chicago      iphone5   16                No
# 255      200        chicago      iphone5   32                No
# 256       80        chicago      iphone4   16  2015-04-29 12:00
# 257      285        chicago     iphone5s   No                No
# 258      600        chicago      iphone6   No                No
# 259      180        chicago      iphone5   No  2015-04-29 12:00
# 260      350        chicago      iphone5   16                No
# 261      650        chicago      iphone6   64                No
# 262      150        chicago      iphone6   64                No
# 263       60        chicago     iphone5c   16                No
# 264      120        chicago      iphone4   No  2015-05-03 11:36
# 265      140        chicago      iphone5   16  2015-05-04 13:43
# 266      200        chicago      iphone5   No                No
# 267      160        chicago      iphone6   No  2015-05-03 11:36
# 268      230        chicago     iphone5s   No                No
# 269      160        chicago           No   No                No
# 270      180        chicago      iphone5   16  2015-05-01 09:42
# 271      160        chicago     iphone5c   No                No
# 272      100        chicago     iphone5s   No                No
# 273      125        chicago     iphone5s   No                No
# 274      150        chicago     iphone4s   No                No
# 275       60        chicago  iphone6plus   No                No
# 276      280        chicago     iphone5s   16  2015-04-30 11:54
# 277       85        chicago     iphone4s   No                No
# 278      400        chicago      iphone6   No  2015-04-29 12:00
# 279      250        chicago      iphone6   No  2015-04-29 12:00
# 280      140        chicago     iphone5s   32  2015-05-02 15:52
# 281      225        chicago      iphone5   No  2015-05-02 15:52
# 282      220        chicago      iphone5   32  2015-05-03 23:38
# 283      600        chicago      iphone6   64                No
# 284      500        chicago      iphone6   No                No
# 285       85        chicago      iphone4    8                No
# 286      525        chicago      iphone6  128                No
# 287      225        chicago      iphone5   No                No
# 288      550        chicago      iphone6   No                No
# 289      150        chicago     iphone4s   16                No
# 290      150        chicago      iphone5   No                No
# 291      225        chicago     iphone5s   64  2015-05-01 09:42
# 292       80        chicago           No   No                No
# 293      460        chicago      iphone6   No                No
# 294      280        chicago     iphone5s   No                No
# 295      235        chicago      iphone5   16  2015-04-30 00:06
# 296      199        chicago      iphone5   No                No
# 297       75        chicago    iphone3gs    8                No
# 298      300        chicago      iphone6  128  2015-05-03 23:38
# 299      299        chicago     iphone5s   No                No
# 300      130        chicago     iphone5s   64  2015-05-03 23:38
# 301      180        chicago     iphone5c   No  2015-04-30 00:06
# 302      800        chicago           No   No  2015-05-04 13:43
# 303      300        chicago     iphone5c   No  2015-05-01 09:43
# 304      120        chicago     iphone4s   No                No
# 305      850        chicago  iphone6plus  128                No
# 306      110        chicago      iphone5   32                No
# 307      150        chicago     iphone5s   32                No
# 308      120        chicago     iphone5s   16                No
# 309      225        chicago      iphone5   16  2015-05-02 15:52
# 310      160        chicago      iphone6   64  2015-05-01 09:43
# 311      215        chicago     iphone4s   16                No
# 312      699        chicago      iphone6   No                No
# 313      220        chicago      iphone5   16                No
# 314      175        chicago     iphone4s   16                No
# 315      180        chicago     iphone5s   16                No
# 316      150        chicago      iphone6   64  2015-05-02 15:52
# 317      110        chicago     iphone5s   16                No
# 318      150        chicago  iphone6plus   No  2015-04-29 12:00
# 319      150        chicago      iphone6   64  2015-05-02 15:52
# 320      350        chicago      iphone6   No  2015-05-01 09:43
# 321      110        chicago     iphone5s   No                No
# 322      120        chicago     iphone5s   No  2015-05-02 15:52
# 323      235        chicago     iphone4s   16                No
# 324      150        chicago  iphone6plus   No                No
# 325      130        chicago      iphone5   16  2015-05-01 11:49
# 326      110        chicago      iphone5   16  2015-05-02 15:52
# 327      599        chicago      iphone6   No                No
# 328      140        chicago     iphone5s   No  2015-05-04 13:43
# 329      185        chicago           No   16  2015-05-02 15:52
# 330      140        chicago      iphone5   16                No
# 331      150        chicago      iphone6  128                No
# 332      375        chicago     iphone5s   16                No
# 333      130        chicago      iphone5   No                No
# 334      110        chicago      iphone4   No  2015-05-02 15:52
# 335      120        chicago      iphone6   No                No
# 336      120        chicago      iphone5   16  2015-05-01 11:49
# 337      650        chicago  iphone6plus   No  2015-04-30 11:54
# 338      250        chicago     iphone5s   No                No
# 339      575        chicago      iphone6   No                No
# 340      750        chicago  iphone6plus   64  2015-04-30 00:07
# 341      699        chicago      iphone6   No                No
# 342      160        chicago  iphone6plus   64  2015-05-01 11:49
# 343      150        chicago  iphone6plus  128  2015-05-02 15:52
# 344      130        chicago     iphone5s   32                No
# 345      300        chicago     iphone5s   16  2015-04-30 00:07
# 346      120        chicago     iphone5s   No  2015-05-02 15:52
# 347      599        chicago      iphone6   No                No
# 348      300        chicago     iphone5s   No                No
# 349      140        chicago      iphone5   16                No
# 350      590        chicago      iphone6   No                No
# 351      550        chicago  iphone6plus   16                No
# 352      100        chicago     iphone4s   No                No
# 353      130        chicago      iphone5   No                No
# 354      275        chicago     iphone5s   16                No
# 355      180        chicago     iphone5c   No  2015-05-01 09:43
# 356      299        chicago     iphone5s   No                No
# 357      400        chicago  iphone6plus   No  2015-04-30 00:07
# 358      120        chicago     iphone5s   32                No
# 359       85        chicago     iphone5c   No                No
# 360      110        chicago      iphone5   32                No
# 361      120        chicago      iphone5   No                No
# 362       80        chicago    iphone3gs    8                No
# 363      150        chicago      iphone6   16  2015-04-30 11:54
# 364      550        chicago  iphone6plus   16                No
# 365      550        chicago  iphone6plus   16                No
# 366      550        chicago  iphone6plus   16                No
# 367      125        chicago      iphone4    8                No
# 368      350        chicago     iphone5s   16                No
# 369      280        chicago     iphone5s   No                No
# 370      500        chicago      iphone6  128                No
# 371      299        chicago     iphone5s   No                No
# 372       90        chicago      iphone4   No                No
# 373       70        chicago     iphone5c   No                No
# 374      200        chicago     iphone4s   16                No
# 375      200        chicago      iphone5   16                No
# 376      200        chicago      iphone5   No                No
# 377      299        chicago     iphone5s   No                No
# 378      550        chicago      iphone6   16                No
# 379       79        chicago      iphone5   No                No
# 380      580        chicago  iphone6plus   No                No
# 381      175        chicago     iphone5c   No                No
# 382      140        chicago     iphone5s   16  2015-05-04 23:45
# 383      170        chicago      iphone6   No  2015-05-04 23:45
# 384      255        chicago      iphone5   No                No
# 385       75        chicago     iphone4s   No                No
# 386      250        chicago     iphone5s   16  2015-05-04 13:43
# 387      160        chicago  iphone6plus   No  2015-05-04 23:45
# 388      100        chicago     iphone5c   16                No
# 389      250        chicago     iphone5s   No                No
# 390      280        chicago     iphone5s   No                No
# 391       80        chicago      iphone4   16                No
# 392      330        chicago     iphone5s   No  2015-04-30 11:54
# 393      250        chicago     iphone5s   16                No
# 394       75        chicago     iphone5s   No                No
# 395      145        chicago      iphone5   16                No
# 396      130        chicago     iphone5s   16                No
# 397      599        chicago      iphone6  128                No
# 398      700        chicago  iphone6plus   64  2015-04-30 00:07
# 399      275        chicago      iphone5   16                No
# 400      200        chicago      iphone5   16                No
# 401      180        chicago      iphone6  128                No
# 402      170        chicago      iphone6   16  2015-05-01 09:43
# 403      120        chicago     iphone5s   16  2015-05-02 15:52
# 404      190        chicago      iphone6  128                No
# 405      130        chicago     iphone5s   16  2015-05-04 13:43
# 406      450        chicago      iphone6   No                No
# 407       80        chicago           No   No                No
# 408      900        chicago      iphone5   16  2015-05-02 15:52
# 409      150        chicago     iphone5s   16                No
# 410       70        chicago     iphone5c   No                No
# 411      200        chicago     iphone5c   16                No
# 412      550        chicago  iphone6plus   No  2015-04-30 11:54
# 413      580        chicago  iphone6plus   No  2015-04-30 11:54
# 414      200        chicago     iphone5c   No                No
# 415       65        chicago     iphone4s   16                No
# 416      380        chicago     iphone5s   64                No
# 417      350        chicago     iphone5s   No                No
# 418   200400        chicago      iphone5   16                No
# 419      850        chicago  iphone6plus  128                No
# 420      150       New York     iphone4s   No                No
# 421      220       New York      iphone5   16                No
# 422      275       New York      iphone5   32                No
# 423      150       New York     iphone4s   16                No
# 424      375       New York     iphone5s   16                No
# 425      150       New York     iphone4s   16                No
# 426      150       New York     iphone4s   16                No
# 427      150       New York     iphone4s   16                No
# 428      399       New York     iphone5s   16                No
# 429       70       New York     iphone4s   16  2015-04-29 12:00
# 430      150       New York      iphone4   32  2015-05-02 15:52
# 431      580       New York      iphone6  128  2015-04-30 00:07
# 432      200       New York     iphone4s   16                No
# 433      200       New York     iphone5s   16  2015-04-30 11:54
# 434      295       New York     iphone5s   16                No
# 435      140       New York      iphone5   16  2015-04-30 11:54
# 436      650       New York  iphone6plus   No                No
# 437      630       New York      iphone6   No  2015-05-02 15:52
# 438      600       New York      iphone6   64  2015-05-03 23:38
# 585       80        houston      iphone5   No  2015-04-29 12:00
# 586      750        houston  iphone6plus  128                No
# 587      600        houston  iphone6plus   No                No
# 588      270        houston     iphone5c   No                No
# 589      300        houston     iphone5s   16                No
# 590       80        houston      iphone5   No  2015-04-29 12:00
# 591      600        houston  iphone6plus   64  2015-05-02 15:52
# 592      550        houston  iphone6plus   64  2015-05-03 11:37
# 593      750        houston  iphone6plus  128                No
# 594      650        houston      iphone6   64  2015-04-30 11:54
# 595      129        houston      iphone6   No  2015-05-04 23:45
# 596      550        houston      iphone6   16                No
# 597      450        houston  iphone6plus   No  2015-05-01 09:43
# 598      510        houston      iphone6   No                No
# 599      500        houston      iphone6   64  2015-05-03 11:37
# 600       65        houston      iphone4   No                No
# 601      375        houston     iphone5s   No  2015-04-30 00:07
# 602      650        houston      iphone6   64  2015-04-29 12:00
# 603      240        houston      iphone5   32                No
# 604      295        houston     iphone5s   32                No
# 605      300        houston      iphone6   16                No
# 606      549        houston      iphone6   16                No
# 607      150        houston     iphone5s   No                No
# 608      200        houston     iphone5s   No                No
# 609      650        houston  iphone6plus   16                No
# 610       82        houston  iphone6plus   64                No
# 611       85        houston  iphone6plus   64                No
# 612      400        houston     iphone5s   16  2015-04-30 00:07
# 613      540        houston      iphone6   16  2015-05-02 15:52
# 614       60        houston     iphone4s   No                No
# 615      250        houston      iphone5   16  2015-04-30 00:07
# 616      600        houston      iphone6   16                No
# 617      450        houston  iphone6plus   No  2015-04-30 00:07
# 618      325        houston     iphone5s   No                No
# 619      600        houston      iphone6   64  2015-04-30 00:07
# 620      425        houston      iphone6   No  2015-05-01 09:43
# 621      425        houston      iphone6   No  2015-05-01 09:43
# 622       75        houston      iphone4   No                No
# 623      250        houston      iphone5   No                No
# 624      280        houston      iphone5   16                No
# 625      250        houston      iphone5   No                No
# 626      800        houston      iphone6   64                No
# 627      900        houston  iphone6plus  128                No
# 628      300        houston     iphone5s   16                No
# 629       82        houston  iphone6plus   64                No
# 630      250        houston     iphone5s   No  2015-05-01 09:43
# 631      300        houston     iphone5s   16                No
# 632      250        houston     iphone5c   No                No
# 633      380        houston  iphone6plus   No  2015-04-30 00:07
# 634      319        houston     iphone5s   No                No
# 635      125        houston      iphone4   No                No
# 636      560        houston      iphone6   16  2015-05-01 09:43
# 637      200        houston  iphone6plus  128  2015-04-30 00:07
# 638      500        houston  iphone6plus   No  2015-05-04 23:45
# 639      400        houston     iphone5s   16                No
# 640      460        houston     iphone5s   No                No
# 641      350        houston     iphone5s   No                No
# 642      250        houston      iphone5   16                No
# 643      125        houston      iphone5   No                No
# 644      200        houston     iphone4s   16                No
# 645      550        houston  iphone6plus   No                No
# 646      500        houston      iphone6   No                No
# 647      200        houston     iphone4s   16                No
# 648      195        houston     iphone5c   16  2015-04-29 12:00
# 649      250        houston     iphone5c    8                No
# 650      200        houston      iphone5   16  2015-05-04 13:43
# 651      549        houston      iphone6   No                No
# 652       80        houston      iphone5   16                No
# 653      229        houston      iphone5   No                No
# 654      319        houston     iphone5s   No                No
# 655      160        houston      iphone6  128                No
# 656      649        houston  iphone6plus   No                No
# 657      180        houston     iphone5s   No  2015-04-30 00:07
# 658      100        houston     iphone5s   No                No
# 659      549        houston      iphone6   No                No
# 660      229        houston      iphone5   No                No
# 661      130        houston     iphone5s   32                No
# 662       89        houston      iphone4   No                No
# 663      649        houston  iphone6plus   No                No
# 664      549        houston      iphone6   No                No
# 665      180        houston     iphone5s   16  2015-04-30 00:07
# 666      359        houston     iphone5s   No                No
# 667      180        houston     iphone5s   No  2015-04-30 00:07
# 668      175        houston      iphone5   32  2015-04-30 11:54
# 669      999        houston      iphone6   No                No
# 670       99        houston      iphone4   No                No
# 671      300        houston           No  128                No
# 672      160        houston      iphone6   16  2015-05-04 13:43
# 673      230        houston     iphone5s   16  2015-05-03 23:39
# 674      500        houston      iphone6   No  2015-05-01 11:50
# 675      130        houston      iphone6   64                No
# 676      160        houston      iphone5   No                No
# 677      120        houston     iphone5s   32                No
# 678      650        houston  iphone6plus   16  2015-05-04 23:45
# 679       89        houston      iphone4   No                No
# 680      280        houston     iphone5s   16                No
# 681      375        houston      iphone6   No                No
# 682      300        houston      iphone5   No                No
# 683      130        houston      iphone6   No  2015-05-04 23:45
# 684       99        houston      iphone5   16  2015-05-04 23:45
# 685      120        houston      iphone5   16  2015-05-04 23:45
# 686      240        houston     iphone5c   No                No
# 687      150        houston      iphone6   64  2015-05-04 23:45
# 688      280        houston     iphone5s   No  2015-04-30 00:07
# 689      280        houston     iphone5s   No  2015-04-30 00:07
# 690       65        houston      iphone5   32                No
# 691      650        houston      iphone6   64                No
# 692      160        houston      iphone5   No                No
# 693      450        houston      iphone6   16                No
# 694      700        houston  iphone6plus   No  2015-05-01 09:43
# 695      110        houston      iphone5   64                No
# 696      500        houston      iphone6   No                No
# 697      580        houston      iphone6   No                No
# 698      196        houston  iphone6plus   No                No
# 699      100        houston      iphone4   16                No
# 700      174        houston      iphone5   64                No
# 701      340        houston     iphone5s   16                No
# 702      340        houston     iphone5s   16                No
# 703      340        houston     iphone5s   16                No
# 704      340        houston     iphone5s   16                No
# 705      340        houston     iphone5s   16                No
# 706      530        houston      iphone6   16                No
# 707      530        houston      iphone6   16                No
# 708      340        houston     iphone5s   16                No
# 709      340        houston     iphone5s   16                No
# 710      340        houston     iphone5s   16                No
# 711      530        houston      iphone6   16                No
# 712      530        houston      iphone6   16                No
# 713      530        houston      iphone6   16                No
# 714      530        houston      iphone6   16                No
# 715      530        houston      iphone6   16                No
# 716      680        houston      iphone6   64                No
# 717      500   philadelphia  iphone6plus   No  2015-04-29 12:00
# 718      450   philadelphia      iphone6   No                No
# 719      230   philadelphia      iphone5   16  2015-05-02 15:53
# 720      210   philadelphia      iphone5   16  2015-04-30 00:07
# 721      650   philadelphia      iphone6   64                No
# 722       75   philadelphia     iphone4s   No                No
# 723      130   philadelphia      iphone5   16  2015-05-03 11:37
# 724      650   philadelphia      iphone6   16                No
# 725      220   philadelphia      iphone5   No                No
# 726      135   philadelphia     iphone4s   16  2015-05-01 09:43
# 727      550   philadelphia      iphone6   No                No
# 728      140   philadelphia      iphone4    8  2015-04-29 12:00
# 2689  -0.138716        12      6     5        1
# 2690  -0.110799        12      8     1        0
# 2691  -0.146447        12      7     5        0
# 2692  -0.147306        12      3     1        1
# 2693  -0.147306        12      3     5        0
# 2694  -0.125831        12      6     5        1
# 2695  -0.145159        12      4     1        0
# 2696  -0.125831        12      6     5        1
# 2697  -0.104442        12      7     3        1
# 2698  -0.108652        12      7     3        0
# 2699  -0.095853        12      8     3        0
# 2700  -0.140434        12      4     1        0
# 2701  -0.138716        12      6     5        1
# 2702  -0.150742        12      2     5        0
# 2703  -0.138716        12      6     5        1
# 2704  -0.108652        12      7     3        0
# 2705  -0.138716        12      4     5        1
# 2706  -0.138716        12      4     5        1
# 2707  -0.108652        12      7     3        0
# 2708  -0.143011        12      0     5        1
# 2709  -0.144729        12      2     5        0
# 2710  -0.143870        12      4     1        0
# 2711  -0.102639        12      8     5        0
# 2712  -0.106504        12      7     3        0
# 2713  -0.137857        12      4     5        0
# 2714  -0.104357        12      8     3        0
# 2715  -0.112947        12      7     1        1
# 2716  -0.136139        12      5     5        1
# 2717  -0.138716        12      0     5        0
# 2718  -0.136998        12      6     1        1
# 2719  -0.138716        12      6     2        1
# 2720  -0.138716        12      6     1        0

# %% [markdown]
# ### Create Test and Training Set

# %%
def predict(df):
    #classifiers and their respective results
    clf = svm.SVC()
    clf2 = svm.SVC()
    rf = RandomForestClassifier(n_estimators=100)
    ab = AdaBoostClassifier(clf2, algorithm='SAMME')
    #ab = AdaBoostClassifier(clf2, n_estimators=100, learning_rate=0.5, algorithm='SAMME',random_state=1)
    lr = LogisticRegression()
    gnb = KNeighborsClassifier()
    clf_results = []
    rf_results = []
    ab_results = []
    lr_results = []
    gnb_results = []
    feature_importance = []

    #Go through each fold of the CV
    cv = cross_validation.KFold(len(df), n_folds=10, shuffle=True)
    for train_indices, test_indices in cv:
        test = pd.DataFrame(columns=["PRICE", "LOCATION", "MODEL", "SIZE", "SOLD_BY"])
        train = df
        for i in test_indices:
            try:
                test = test.append(df.iloc[i])
                train = train.drop([i])
            except ValueError:
                continue
        Y_train = train["SOLD_BY"]
        X_train = train.drop("SOLD_BY", 1)
        Y_test = test["SOLD_BY"]
        X_test = test.drop("SOLD_BY", 1)

        #SVM
        clf.fit(X_train, Y_train)
        clf_score = clf.score(X_test, Y_test)
        clf_results.append(clf_score)
        #all_predictions.append(clf.predict(X_test))

        #RandomForestClassifier
        rf.fit(X_train, Y_train)
        rf_score = rf.score(X_test, Y_test)
        rf_results.append(rf_score)
        feature_importance.append(rf.feature_importances_)
        #all_predictions.append(rf.predict(X_test))

        #Adaboosted SVM
        ab.fit(X_train, Y_train)
        ab_score = ab.score(X_test, Y_test)
        ab_results.append(ab_score)
        #all_predictions.append(ab.predict(X_test))

        #Logistic Regression
        lr.fit(X_train, Y_train)
        lr_score = lr.score(X_test, Y_test)
        lr_results.append(lr_score)
        #all_predictions.append(lr.predict(X_test))
        
        #Gaussian Naive Bayes
        gnb.fit(X_train, Y_train)
        gnb_score = gnb.score(X_test, Y_test)
        gnb_results.append(gnb_score)
        
    return clf_results, rf_results, ab_results, lr_results, gnb_results, feature_importance

# %%
def average_feature_importance(feature_importance):
    result = []
    count = 0
    price_avg = 0
    location_avg = 0
    model_avg = 0
    size_avg = 0
    for x in feature_importance:
        price_avg += x[0]
        location_avg += x[1]
        model_avg += x[2]
        size_avg += x[3]
        count += 1
    price_avg = price_avg/count
    location_avg = location_avg/count
    model_avg = model_avg/count
    size_avg = size_avg/count
    result = [price_avg, location_avg, model_avg, size_avg]
    return result

# %%
print "3 DAYS PREDICTIONS"
clf_results, rf_results, ab_results, lr_results, gnb_results, feature_importance = predict(df_3days)
print "SVM"
#print clf_results
print np.mean(clf_results)
print "Random Forest Classifier"
#print rf_results
print np.mean(rf_results)
print "Adaboosted (SVM)"
#print ab_results
print np.mean(ab_results)
print "Logistic Regression"
#print lr_results
print np.mean(lr_results)
print "Gaussian Naive Bayes"
#print gnb_results
print np.mean(gnb_results)
print "Feature Importance for RFC (greatest to least): PRICE, LOCATION, MODEL, SIZE"
avg = average_feature_importance(feature_importance)
print "PRICE: %f" % avg[0]
print "LOCATION: %f" % avg[1]
print "MODEL: %f" % avg[2]
print "SIZE: %f" % avg[3]

print ""
print "WEEK PREDICTIONS"
clf_results, rf_results, ab_results, lr_results, gnb_results, feature_importance = predict(df_week)
print "SVM"
#print clf_results
print np.mean(clf_results)
print "Random Forest Classifier"
#print rf_results
print np.mean(rf_results)
print "Adaboosted (SVM)"
#print ab_results
print np.mean(ab_results)
print "Logistic Regression"
#print lr_results
print np.mean(lr_results)
print "Gaussian Naive Bayes"
#print gnb_results
print np.mean(gnb_results)
print "Feature Importance for RFC (greatest to least): PRICE, LOCATION, MODEL, SIZE"
avg = average_feature_importance(feature_importance)
print "PRICE: %f" % avg[0]
print "LOCATION: %f" % avg[1]
print "MODEL: %f" % avg[2]
print "SIZE: %f" % avg[3]
# Out:
# 3 DAYS PREDICTIONS
# SVM
# 0.842557768924
# Random Forest Classifier
# 0.884811155378
# Adaboosted (SVM)
# 0.841760956175
# Logistic Regression
# 0.841760956175
# Gaussian Naive Bayes
# 0.832999203187
# Feature Importance for RFC (greatest to least): PRICE, LOCATION, MODEL, SIZE
# PRICE: 0.455977
# LOCATION: 0.303214
# MODEL: 0.131821
# SIZE: 0.108987
#
# WEEK PREDICTIONS
# SVM
# 0.628813833226
# Random Forest Classifier
# 0.651597177332
# Adaboosted (SVM)
# 0.640202811894
# Logistic Regression
# 0.635799127343
# Gaussian Naive Bayes
# 0.623297780651
# Feature Importance for RFC (greatest to least): PRICE, LOCATION, MODEL, SIZE
# PRICE: 0.447888
# LOCATION: 0.328800
# MODEL: 0.137114
# SIZE: 0.086198

# %%
print "Baseline"
print pd.Series(df_week['SOLD_BY'].values.ravel()).value_counts()
print pd.Series(df_3days['SOLD_BY'].values.ravel()).value_counts()
# Out:
# Baseline
# 0    1742
# 1     979
# dtype: int64
# 0    2112
# 1     397
# dtype: int64

# %%
print 1742/(1742+979)
print 2112/(2112+397)
# Out:
# 0.640205806689
# 0.841769629334

# %%
df_3days.to_csv('alex3days.csv')
df_week.to_csv('alex7days.csv')
